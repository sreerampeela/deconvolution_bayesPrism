# %% [markdown]
# # getting a gene expression matrix from all samples

# %%
# load libraries
import pandas as pd
import numpy as np

import os

# %%
sample_info_file = pd.read_csv("gdc_sample_sheet.tsv", header=0, sep="\t")
exp_files = [i for i in os.listdir() if i.endswith("star_gene_counts.tsv") is True]

# %%
print(exp_files)
with open("file_order.txt", "w", encoding="utf-8", newline="\n") as tmpfile:
  tmpfile.write("\n".join(exp_files))
# Out:
# ['00a26384-1b1c-4db4-9664-75fb9b3febdb.rna_seq.augmented_star_gene_counts.tsv', '01661d94-fc16-4456-95cf-a5fa4e1e196c.rna_seq.augmented_star_gene_counts.tsv', '01900aab-4c12-4198-b41f-ff638e5abe3b.rna_seq.augmented_star_gene_counts.tsv', '01ae5613-1c58-4d02-8fd3-47d35d71c22d.rna_seq.augmented_star_gene_counts.tsv', '01f6286b-8422-4f16-bec3-871c86396790.rna_seq.augmented_star_gene_counts.tsv', '021d9e06-9d27-400c-8776-08e89c817b46.rna_seq.augmented_star_gene_counts.tsv', '02423743-43b4-494b-acd9-1cd3bcd3d395.rna_seq.augmented_star_gene_counts.tsv', '02a4ccea-1464-4664-bc44-bb6569a34608.rna_seq.augmented_star_gene_counts.tsv', '02a50d1b-ff62-4936-a0ce-ac0e22a5b41c.rna_seq.augmented_star_gene_counts.tsv', '02bbe1b1-44ff-426b-a40e-47a01bc4cf7d.rna_seq.augmented_star_gene_counts.tsv', '032e5aa7-8028-48ad-8fe4-6a5cc6aee5cb.rna_seq.augmented_star_gene_counts.tsv', '034f8d01-f664-494b-bc04-77485000611f.rna_seq.augmented_star_gene_counts.tsv', '0361ec21-e83f-40a9-b825-d92487b1239a.rna_seq.augmented_star_gene_counts.tsv', '0394cdb2-85e8-4cea-b572-4cb4ed779774.rna_seq.augmented_star_gene_counts.tsv', '039eaafb-c311-45ff-9df7-30c1b0bab00a.rna_seq.augmented_star_gene_counts.tsv', '03d891b3-8faf-4384-94ce-2015f1ca5df0.rna_seq.augmented_star_gene_counts.tsv', '04026251-0cf6-4889-83b4-8a46881470b5.rna_seq.augmented_star_gene_counts.tsv', '040e40de-4c19-423f-98dc-151e2633d085.rna_seq.augmented_star_gene_counts.tsv', '046c3754-b22c-4bce-93c7-29b9da173d33.rna_seq.augmented_star_gene_counts.tsv', '04c428b5-d0b9-4ecf-86e8-8a42dc4cbb5e.rna_seq.augmented_star_gene_counts.tsv', '04de1f79-fdfc-4662-bab2-a3ed667c7dea.rna_seq.augmented_star_gene_counts.tsv', '04ed1bfb-533f-4d97-a7e4-3e7bab103485.rna_seq.augmented_star_gene_counts.tsv', '053442de-6d8a-4811-b03c-be1c7a3f207c.rna_seq.augmented_star_gene_counts.tsv', '0557d817-20e0-496f-840a-7a15d6da1694.rna_seq.augmented_star_gene_counts.tsv', '05b55f88-290a-4abd-bbc3-44561ba1f8b7.rna_seq.augmented_star_gene_counts.tsv', '05ddce6e-57b0-4b78-9955-7c1b4c564498.rna_seq.augmented
# 1  7836ae1b-35ea-4273-b9ed-2bb72f1b3d06.rna_seq.a...  Transcriptome Profiling
# 2  9d1c711e-5a41-48c0-af11-ef2e94c0b1e3.rna_seq.a...  Transcriptome Profiling
# 3  24ee1455-865e-4bf0-a7ce-de2d0de3465f.rna_seq.a...  Transcriptome Profiling
# 4  e453ca55-fabb-4b24-87b9-364dae2beda9.rna_seq.a...  Transcriptome Profiling
#
#                         Data Type Project ID            Case ID  \
# 0  Gene Expression Quantification  HCMI-CMDC  HCM-CSHL-0078-C25
# 1  Gene Expression Quantification  HCMI-CMDC  HCM-CSHL-0246-C19
# 2  Gene Expression Quantification  HCMI-CMDC  HCM-BROD-0110-C25
# 3  Gene Expression Quantification  HCMI-CMDC  HCM-CSHL-0238-C18
# 4  Gene Expression Quantification  HCMI-CMDC  HCM-CSHL-0058-C34
#
#                Sample ID    Sample Type
# 0  HCM-CSHL-0078-C25-01A  Primary Tumor
# 1  HCM-CSHL-0246-C19-01B  Primary Tumor
# 2  HCM-BROD-0110-C25-01A  Primary Tumor
# 3  HCM-CSHL-0238-C18-01B  Primary Tumor
# 4  HCM-CSHL-0058-C34-01B  Primary Tumor

# %% [markdown]
# From sample info file, use sample id as identifier for each sample

# %%
def getCounts(filename, sample_info, expressionFiles):
  df = pd.read_csv(filename, header=1, sep = "\t")
  # print(filename)
  # print(df.head())
  geneids = df["gene_id"][4:].values
  genenames = df["gene_name"][4:].values
  if "unstranded" in df.columns:
    tpmvals = df["unstranded"][4:].values
  # print(f"{tpmvals[0:5]}\t{geneids[0:5]}")
    sampleName = filename.split(".")[0]
  # print(sampleName)
    counts_series = pd.Series(tpmvals, index=genenames)
    return counts_series, sampleName
  else:
    return f"column not found for {filename}"

# %%
dfKeys = []
dfdata = []
for fileid in exp_files:
  counts, sampleid = getCounts(filename=fileid, sample_info=sample_info_file, expressionFiles=exp_files)
  dfKeys.append(sampleid)
  dfdata.append(counts)
  
print(len(dfKeys), len(dfdata))
# Out:
# 1223 1223

# %%
df_dict = {sample:data for sample,data in zip(dfKeys, dfdata)}

# %%
final_df = pd.DataFrame(data=df_dict)
print(final_df.head())
# Out:
#           00a26384-1b1c-4db4-9664-75fb9b3febdb  \
# TSPAN6                                    3888
# TNMD                                         9
# DPM1                                      1458
# SCYL3                                     2135
# C1orf112                                   440
#
#           01661d94-fc16-4456-95cf-a5fa4e1e196c  \
# TSPAN6                                    1372
# TNMD                                        27
# DPM1                                      2135
# SCYL3                                     2385
# C1orf112                                  1075
#
#           01900aab-4c12-4198-b41f-ff638e5abe3b  \
# TSPAN6                                    4914
# TNMD                                        19
# DPM1                                      1507
# SCYL3                                     1404
# C1orf112                                   348
#
#           01ae5613-1c58-4d02-8fd3-47d35d71c22d  \
# TSPAN6                                    5055
# TNMD                                         6
# DPM1                                      1849
# SCYL3                                     1694
# C1orf112                                   393
#
#           01f6286b-8422-4f16-bec3-871c86396790  \
# TSPAN6                                     447
# TNMD                                         8
# DPM1                                      1719
# SCYL3                                     1003
# C1orf112                                   253
#
#           021d9e06-9d27-400c-8776-08e89c817b46  \
# TSPAN6                                    2971
# TNMD                                        24
# DPM1                                      1956
# SCYL3                                      599
# C1orf112                                   210
#
#           02423743-43b4-494b-acd9-1cd3bcd3d395  \
# TSPAN6                                    1445
# TNMD                                        11
# DPM1                                      4161
# SCYL3                                     3274
# C1orf112                                  1114
#
#           02a4ccea-1464-4664-bc44-bb6569a34608  \
# TSPAN6                                     457
# TNMD                                         0
# DPM1                                      1949
# SCYL3                                     4082
# C1orf112                                  1351
#
#           02a50d1b-ff62-4936-a0ce-ac0e22a5b41c  \
# TSPAN6                                    2514
# TNMD                                         0
# DPM1                                      3064
# SCYL3                                     1562
# C1orf112                                   897
#
#           02bbe1b1-44ff-426b-a40e-47a01bc4cf7d  ...  \
# TSPAN6                                    3052  ...
# TNMD                                       141  ...
# DPM1                                      2129  ...
# SCYL3                                     1190  ...
# C1orf112                                  1026  ...
#
#           fe15bb7d-6469-4778-9dc8-9e4c5877942c  \
# TSPAN6                                    5074
# TNMD                                        47
# DPM1                                      4795
# SCYL3                                      999
# C1orf112                                  3295
#
#           fe379cd5-d51b-44b3-9adf-49e2cc3b0bf5  \
# TSPAN6                                    3101
# TNMD                                        27
# DPM1                                      1597
# SCYL3                                     1849
# C1orf112                                   403
#
#           fe8166b9-08e8-477b-9122-0e9194f34818  \
# TSPAN6                                    1948
# TNMD                                         0
# DPM1                                      3691
# SCYL3                                     1841
# C1orf112                                  1694
#
#           fead73ce-2e66-4647-8b6c-b8bbdaaf30fe  \
# TSPAN6                                    3015
# TNMD                                         4
# DPM1                                      2815
# SCYL3                                     1318
# C1orf112                                   738
#
#           feb7140e-d822-4462-8dfa-7a63805ac740  \
# TSPAN6                                    6342
# TNMD                                       330
# DPM1                                      2165
# SCYL3                                     2007
# C1orf112                                   312
#
#           fefb685b-91fc-4837-b612-73be3c4d941e  \
# TSPAN6                                   13591
# TNMD                                         3
# DPM1                                      1864
# SCYL3                                      752
# C1orf112                                   301
#
#           ff0feb3e-6d14-4297-ac23-1eb397663ec3  \
# TSPAN6                                     648
# TNMD                                         0
# DPM1                                      1475
# SCYL3                                     1412
# C1orf112                                   299
#
#           ff93cbad-7bdf-4e5d-81c7-95aacaa3bee9  \
# TSPAN6                                    9057
# TNMD                                        69
# DPM1                                     11641
# SCYL3                                     1201
# C1orf112                                  1050
#
#           ffe82e73-0990-4d3d-a4d1-7d4e169dfdf5  \
# TSPAN6                                     561
# TNMD                                        14
# DPM1                                      2486
# SCYL3                                     1335
# C1orf112                                   330
#
#           fff3f42f-5e42-4653-b91b-1676f914e9fa
# TSPAN6                                    2199
# TNMD                                         5
# DPM1                                      2456
# SCYL3                                      478
# C1orf112                                   291
#
# [5 rows x 1223 columns]

# %%
final_df.to_csv("raw_counts.tsv", sep = "\t", index=True)
